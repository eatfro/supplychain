# %%
import pandas as pd

# %%
# Sample data
df = pd.DataFrame({
    'date_string': ['2025-09-20', '2025-09-21', '2025-09-22'],
    'value': [100, 110, 105]
})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date_string  3 non-null      object
#  1   value        3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 176.0+ bytes

# %%
# Convert the 'date_string' column to datetime and set it as the index
df['date_string'] = pd.to_datetime(df['date_string'])
df = df.set_index('date_string')

print(df)
# Out:
#              value
# date_string
# 2025-09-20     100
# 2025-09-21     110
# 2025-09-22     105
